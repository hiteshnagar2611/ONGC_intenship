# %% [markdown]
# ## Facies classification using Machine Learning Support Vector Machine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as color
import seaborn as sns
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, recall_score, precision_score, classification_report, confusion_matrix
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC

import warnings
warnings.filterwarnings("ignore")

# %%
#Load data
data = pd.read_csv('Facies_vectors.csv')
data
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#        PHIND     PE  NM_M  RELPOS
# 0     11.915  4.600     1   1.000
# 1     12.565  4.100     1   0.979
# 2     13.050  3.600     1   0.957
# 3     13.115  3.500     1   0.936
# 4     13.300  3.400     1   0.915
# ...      ...    ...   ...     ...
# 4144   7.254  3.617     2   0.685
# 4145   8.013  3.344     2   0.677
# 4146   8.013  3.190     2   0.669
# 4147   7.708  3.152     2   0.661
# 4148   6.668  3.295     2   0.653
#
# [4149 rows x 11 columns]

# %%
#Label of Facies
labels = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS','WS', 'D','PS', 'BS'] 
data['Facies_Label']=np.select([data['Facies'] == 1,
                                data['Facies'] == 2,
                                data['Facies'] == 3,
                                data['Facies'] == 4,
                                data['Facies'] == 5,
                                data['Facies'] == 6,
                                data['Facies'] == 7,
                                data['Facies'] == 8,
                                data['Facies'] == 9,]
                                ,labels,default='')

# %%
#Unique items in a column that is categorical
data['Well Name'] = data['Well Name'].astype('category')
data['Formation'] = data['Formation'].astype('category')
data['Facies_Label'] = data['Facies_Label'].astype('category')

# %%
data
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#        PHIND     PE  NM_M  RELPOS Facies_Label
# 0     11.915  4.600     1   1.000         FSiS
# 1     12.565  4.100     1   0.979         FSiS
# 2     13.050  3.600     1   0.957         FSiS
# 3     13.115  3.500     1   0.936         FSiS
# 4     13.300  3.400     1   0.915         FSiS
# ...      ...    ...   ...     ...          ...
# 4144   7.254  3.617     2   0.685           MS
# 4145   8.013  3.344     2   0.677           MS
# 4146   8.013  3.190     2   0.669           MS
# 4147   7.708  3.152     2   0.661           MS
# 4148   6.668  3.295     2   0.653           MS
#
# [4149 rows x 12 columns]

# %%
#Set Index Depth
data.set_index('Depth',inplace=True)

# %%
#Group by Well Name
data.groupby("Well Name").count()
# Out:
#                  Facies  Formation   GR  ILD_log10  DeltaPHI  PHIND   PE  \
# Well Name
# ALEXANDER D         466        466  466        466       466    466    0
# CHURCHMAN BIBLE     404        404  404        404       404    404  404
# CROSS H CATTLE      501        501  501        501       501    501  501
# KIMZEY A            439        439  439        439       439    439    0
# LUKE G U            461        461  461        461       461    461  461
# NEWBY               463        463  463        463       463    463  463
# NOLAN               415        415  415        415       415    415  415
# Recruit F9           80         80   80         80        80     80   68
# SHANKLE             449        449  449        449       449    449  449
# SHRIMPLIN           471        471  471        471       471    471  471
#
#                  NM_M  RELPOS  Facies_Label
# Well Name
# ALEXANDER D       466     466           466
# CHURCHMAN BIBLE   404     404           404
# CROSS H CATTLE    501     501           501
# KIMZEY A          439     439           439
# LUKE G U          461     461           461
# NEWBY             463     463           463
# NOLAN             415     415           415
# Recruit F9         80      80            80
# SHANKLE           449     449           449
# SHRIMPLIN         471     471           471

# %%
#Delete Rows with Missing Data
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3232 entries, 2793.0 to 3122.5
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Facies        3232 non-null   int64
#  1   Formation     3232 non-null   category
#  2   Well Name     3232 non-null   category
#  3   GR            3232 non-null   float64
#  4   ILD_log10     3232 non-null   float64
#  5   DeltaPHI      3232 non-null   float64
#  6   PHIND         3232 non-null   float64
#  7   PE            3232 non-null   float64
#  8   NM_M          3232 non-null   int64
#  9   RELPOS        3232 non-null   float64
#  10  Facies_Label  3232 non-null   category
# dtypes: category(3), float64(6), int64(2)
# memory usage: 238.1 KB

# %%
#Using well "SHANKLE" for accuracy evaluation
test_well = data[data['Well Name'] == 'SHANKLE'] #New data to test
data = data[data['Well Name'] != 'SHANKLE']

# %%
X = data.drop(['Facies','Formation','Well Name','Facies_Label'], axis = 1) #Features: Feature vector
y = data['Facies'] #Target: Facies

# %%
X
# Out:
#             GR  ILD_log10  DeltaPHI   PHIND     PE  NM_M  RELPOS
# Depth
# 2793.0  77.450      0.664     9.900  11.915  4.600     1   1.000
# 2793.5  78.260      0.661    14.200  12.565  4.100     1   0.979
# 2794.0  79.050      0.658    14.800  13.050  3.600     1   0.957
# 2794.5  86.100      0.655    13.900  13.115  3.500     1   0.936
# 2795.0  74.580      0.647    13.500  13.300  3.400     1   0.915
# ...        ...        ...       ...     ...    ...   ...     ...
# 3120.5  46.719      0.947     1.828   7.254  3.617     2   0.685
# 3121.0  44.563      0.953     2.241   8.013  3.344     2   0.677
# 3121.5  49.719      0.964     2.925   8.013  3.190     2   0.669
# 3122.0  51.469      0.965     3.083   7.708  3.152     2   0.661
# 3122.5  50.031      0.970     2.609   6.668  3.295     2   0.653
#
# [2783 rows x 7 columns]

# %% [markdown]
# ## Data Split (Test/Train)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1000)
print('Dimensions of X_train:',X_train.shape)
print('Dimensions of X_test:',X_test.shape)
# Out:
# Dimensions of X_train: (1948, 7)
# Dimensions of X_test: (835, 7)

# %%
X_train
# Out:
#             GR  ILD_log10  DeltaPHI   PHIND     PE  NM_M  RELPOS
# Depth
# 2931.5  46.813   0.857000    -0.436   4.880  4.273     2   0.902
# 3004.0  49.860   0.910000     7.600   7.585  4.800     2   0.480
# 2714.0  15.340   0.792000     0.100   9.750  5.300     2   0.789
# 3121.5  49.719   0.964000     2.925   8.013  3.190     2   0.669
# 2857.5  90.313   0.581000     5.634  13.458  3.395     1   0.818
# ...        ...        ...       ...     ...    ...   ...     ...
# 2809.0  23.688   0.777572    -2.200   9.400  4.449     2   0.971
# 2927.0  53.125   0.826000     1.122   4.835  4.008     2   1.000
# 2927.5  73.970   0.498000     5.900  16.850  3.500     1   0.222
# 2674.5  76.510   0.623000     6.600  23.600  2.600     1   0.795
# 2866.5  59.625   0.292000     6.294  19.487  2.947     1   0.409
#
# [1948 rows x 7 columns]

# %% [markdown]
# ## Data Preprocessing
# ### Feature Transform: Robust Scaler

# %%
# Robust Scaler
rscaler = RobustScaler() #instantiate
rscaler.fit(X_train)
# Out:
# RobustScaler()

# %%
X_train_scaled = rscaler.transform(X_train) # transform the train dataset to standardized data

# Original training dataset
print("Original median : %s " % rscaler.center_)
print("Original IQR : %s " % rscaler.scale_)

#Scaled training dataset
print("Scaled median : %s " % np.median(X_train_scaled,axis=0))
print("Scaled IQR : %s " % (np.percentile(X_train_scaled, 75,axis=0)-np.percentile(X_train_scaled, 25,axis=0)))
# Out:
# Original median : [65.1225  0.631   3.4995 11.85    3.608   2.      0.5435]
# Original IQR : [35.7625   0.314    5.19425  7.97225  1.2      1.       0.505  ]
# Scaled median : [ 0.00000000e+00  0.00000000e+00 -4.27514469e-17  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.09938100e-16]
# Scaled IQR : [1. 1. 1. 1. 1. 1. 1.]

# %%
#Scale the test data using the parameters learnt from the training dataset
X_test_scaled  = rscaler.transform(X_test)

print("Median of scaled test data: %s" % np.median(X_test_scaled,axis=0))
print("IQR of scaled test data: %s " % (np.percentile(X_test_scaled, 75,axis=0)-np.percentile(X_test_scaled, 25,axis=0)))
# Out:
# Median of scaled test data: [ 0.04727019 -0.03327247  0.03860038  0.02333093 -0.00666667  0.
#  -0.08613861]
# IQR of scaled test data: [0.93463824 1.00955414 1.00110699 1.00034495 1.         1.
#  0.93069307]

# %%
X_train=pd.DataFrame(X_train_scaled,index=X_train.index, columns=X_test.columns)
X_test=pd.DataFrame(X_test_scaled,index=X_test.index, columns=X_test.columns)

# %%
X_train
# Out:
#               GR  ILD_log10  DeltaPHI     PHIND        PE  NM_M    RELPOS
# Depth
# 2931.5 -0.511975   0.719745 -0.757665 -0.874283  0.554167   0.0  0.709901
# 3004.0 -0.426774   0.888535  0.789431 -0.534981  0.993333   0.0 -0.125743
# 2714.0 -1.392031   0.512739 -0.654474 -0.263414  1.410000   0.0  0.486139
# 3121.5 -0.430717   1.060510 -0.110603 -0.481294 -0.348333   0.0  0.248515
# 2857.5  0.704383  -0.159236  0.410935  0.201700 -0.177500  -1.0  0.543564
# ...          ...        ...       ...       ...       ...   ...       ...
# 2809.0 -1.158602   0.466789 -1.097271 -0.307316  0.700833   0.0  0.846535
# 2927.0 -0.335477   0.621019 -0.457718 -0.879927  0.333333   0.0  0.903960
# 2927.5  0.247396  -0.423567  0.462146  0.627176 -0.090000  -1.0 -0.636634
# 2674.5  0.318420  -0.025478  0.596910  1.473862 -0.840000  -1.0  0.498020
# 2866.5 -0.153722  -1.079618  0.537999  0.957948 -0.550833  -1.0 -0.266337
#
# [1948 rows x 7 columns]

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.model_selection import GridSearchCV 
  
#Defining parameter range 
Tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
                     'C': [0.1, 1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]},
                    {'kernel': ['poly'],'C': [1, 10, 100, 1000],'degree': [2,3,4]}]
  
svc_mod = GridSearchCV(SVC(), Tuned_parameters, refit = True, verbose = 3)

# %%
svc_mod.fit(X_train, y_train) 
svc_mod.best_estimator_
# Out:
# Fitting 5 folds for each of 41 candidates, totalling 205 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.559 total time=   0.3s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.538 total time=   0.1s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.562 total time=   0.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.560 total time=   0.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.540 total time=   0.1s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.518 total time=   0.1s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.495 total time=   0.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.523 total time=   0.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.496 total time=   0.1s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.532 total time=   0.1s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.379 total time=   0.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.364 total time=   0.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.379 total time=   0.1s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.396 total time=   0.1s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.375 total time=   0.1s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.233 total time=   0.1s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.233 total time=   0.1s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.233 total time=   0.1s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.233 total time=   0.1s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.677 total time=   0.1s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.687 total time=   0.1s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.681 total time=   0.1s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.661 total time=   0.1s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.585 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.585 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.610 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.607 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.625 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.505 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.490 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.541 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.491 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.519 total time=   0.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.382 total time=   0.1s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.367 total time=   0.1s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.379 total time=   0.1s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.396 total time=   0.1s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.375 total time=   0.1s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.233 total time=   0.1s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.233 total time=   0.1s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.231 total time=   0.1s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.728 total time=   0.2s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.713 total time=   0.1s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.700 total time=   0.1s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.684 total time=   0.1s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.699 total time=   0.1s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.626 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.645 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.632 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.577 total time=   0.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.585 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.605 total time=   0.1s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.591 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.599 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.492 total time=   0.1s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.487 total time=   0.1s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.533 total time=   0.1s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.483 total time=   0.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.491 total time=   0.1s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.382 total time=   0.1s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.367 total time=   0.1s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.379 total time=   0.1s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.396 total time=   0.1s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.375 total time=   0.1s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.674 total time=   0.1s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.708 total time=   0.1s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.702 total time=   0.1s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.681 total time=   0.1s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.641 total time=   0.1s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.672 total time=   0.1s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.651 total time=   0.1s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.671 total time=   0.1s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.648 total time=   0.1s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.597 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.615 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.613 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.620 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.620 total time=   0.1s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.569 total time=   0.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.579 total time=   0.1s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.613 total time=   0.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.591 total time=   0.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.573 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.492 total time=   0.1s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.479 total time=   0.1s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.536 total time=   0.1s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.481 total time=   0.1s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.488 total time=   0.1s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.662 total time=   0.1s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.649 total time=   0.1s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.677 total time=   0.1s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.699 total time=   0.1s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.663 total time=   0.1s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.679 total time=   0.3s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.679 total time=   0.4s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.3s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.658 total time=   0.3s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.663 total time=   0.3s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.600 total time=   0.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.633 total time=   0.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.623 total time=   0.1s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.648 total time=   0.1s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.625 total time=   0.1s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.595 total time=   0.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.595 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.605 total time=   0.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.602 total time=   0.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.607 total time=   0.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.564 total time=   0.1s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.585 total time=   0.1s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.600 total time=   0.1s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.568 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.568 total time=   0.1s
# [CV 1/5] END ................C=1, kernel=linear;, score=0.577 total time=   0.0s
# [CV 2/5] END ................C=1, kernel=linear;, score=0.587 total time=   0.0s
# [CV 3/5] END ................C=1, kernel=linear;, score=0.597 total time=   0.0s
# [CV 4/5] END ................C=1, kernel=linear;, score=0.596 total time=   0.0s
# [CV 5/5] END ................C=1, kernel=linear;, score=0.591 total time=   0.0s
# [CV 1/5] END ...............C=10, kernel=linear;, score=0.577 total time=   0.0s
# [CV 2/5] END ...............C=10, kernel=linear;, score=0.587 total time=   0.1s
# [CV 3/5] END ...............C=10, kernel=linear;, score=0.587 total time=   0.0s
# [CV 4/5] END ...............C=10, kernel=linear;, score=0.599 total time=   0.0s
# [CV 5/5] END ...............C=10, kernel=linear;, score=0.596 total time=   0.0s
# [CV 1/5] END ..............C=100, kernel=linear;, score=0.579 total time=   0.5s
# [CV 2/5] END ..............C=100, kernel=linear;, score=0.590 total time=   0.5s
# [CV 3/5] END ..............C=100, kernel=linear;, score=0.587 total time=   0.5s
# [CV 4/5] END ..............C=100, kernel=linear;, score=0.602 total time=   0.5s
# [CV 5/5] END ..............C=100, kernel=linear;, score=0.594 total time=   0.6s
# [CV 1/5] END .............C=1000, kernel=linear;, score=0.579 total time=  31.9s
# [CV 2/5] END .............C=1000, kernel=linear;, score=0.590 total time=  24.6s
# [CV 3/5] END .............C=1000, kernel=linear;, score=0.590 total time=   7.2s
# [CV 4/5] END .............C=1000, kernel=linear;, score=0.599 total time=  15.1s
# [CV 5/5] END .............C=1000, kernel=linear;, score=0.594 total time=  37.0s
# [CV 1/5] END ........C=1, degree=2, kernel=poly;, score=0.567 total time=   0.0s
# [CV 2/5] END ........C=1, degree=2, kernel=poly;, score=0.541 total time=   0.0s
# [CV 3/5] END ........C=1, degree=2, kernel=poly;, score=0.592 total time=   0.0s
# [CV 4/5] END ........C=1, degree=2, kernel=poly;, score=0.555 total time=   0.0s
# [CV 5/5] END ........C=1, degree=2, kernel=poly;, score=0.576 total time=   0.0s
# [CV 1/5] END ........C=1, degree=3, kernel=poly;, score=0.587 total time=   0.0s
# [CV 2/5] END ........C=1, degree=3, kernel=poly;, score=0.572 total time=   0.0s
# [CV 3/5] END ........C=1, degree=3, kernel=poly;, score=0.585 total time=   0.0s
# [CV 4/5] END ........C=1, degree=3, kernel=poly;, score=0.558 total time=   0.0s
# [CV 5/5] END ........C=1, degree=3, kernel=poly;, score=0.578 total time=   0.0s
# [CV 1/5] END ........C=1, degree=4, kernel=poly;, score=0.531 total time=   0.0s
# [CV 2/5] END ........C=1, degree=4, kernel=poly;, score=0.549 total time=   0.0s
# [CV 3/5] END ........C=1, degree=4, kernel=poly;, score=0.544 total time=   0.0s
# [CV 4/5] END ........C=1, degree=4, kernel=poly;, score=0.532 total time=   0.0s
# [CV 5/5] END ........C=1, degree=4, kernel=poly;, score=0.558 total time=   0.0s
# [CV 1/5] END .......C=10, degree=2, kernel=poly;, score=0.562 total time=   0.0s
# [CV 2/5] END .......C=10, degree=2, kernel=poly;, score=0.605 total time=   0.0s
# [CV 3/5] END .......C=10, degree=2, kernel=poly;, score=0.628 total time=   0.0s
# [CV 4/5] END .......C=10, degree=2, kernel=poly;, score=0.586 total time=   0.0s
# [CV 5/5] END .......C=10, degree=2, kernel=poly;, score=0.622 total time=   0.0s
# [CV 1/5] END .......C=10, degree=3, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END .......C=10, degree=3, kernel=poly;, score=0.631 total time=   0.0s
# [CV 3/5] END .......C=10, degree=3, kernel=poly;, score=0.623 total time=   0.0s
# [CV 4/5] END .......C=10, degree=3, kernel=poly;, score=0.609 total time=   0.0s
# [CV 5/5] END .......C=10, degree=3, kernel=poly;, score=0.609 total time=   0.0s
# [CV 1/5] END .......C=10, degree=4, kernel=poly;, score=0.592 total time=   0.0s
# [CV 2/5] END .......C=10, degree=4, kernel=poly;, score=0.636 total time=   0.0s
# [CV 3/5] END .......C=10, degree=4, kernel=poly;, score=0.608 total time=   0.0s
# [CV 4/5] END .......C=10, degree=4, kernel=poly;, score=0.607 total time=   0.0s
# [CV 5/5] END .......C=10, degree=4, kernel=poly;, score=0.599 total time=   0.1s
# [CV 1/5] END ......C=100, degree=2, kernel=poly;, score=0.572 total time=   0.2s
# [CV 2/5] END ......C=100, degree=2, kernel=poly;, score=0.631 total time=   0.3s
# [CV 3/5] END ......C=100, degree=2, kernel=poly;, score=0.626 total time=   0.2s
# [CV 4/5] END ......C=100, degree=2, kernel=poly;, score=0.589 total time=   0.2s
# [CV 5/5] END ......C=100, degree=2, kernel=poly;, score=0.617 total time=   0.2s
# [CV 1/5] END ......C=100, degree=3, kernel=poly;, score=0.628 total time=   0.2s
# [CV 2/5] END ......C=100, degree=3, kernel=poly;, score=0.667 total time=   0.4s
# [CV 3/5] END ......C=100, degree=3, kernel=poly;, score=0.641 total time=   0.4s
# [CV 4/5] END ......C=100, degree=3, kernel=poly;, score=0.609 total time=   0.4s
# [CV 5/5] END ......C=100, degree=3, kernel=poly;, score=0.617 total time=   0.2s
# [CV 1/5] END ......C=100, degree=4, kernel=poly;, score=0.610 total time=   0.2s
# [CV 2/5] END ......C=100, degree=4, kernel=poly;, score=0.662 total time=   0.2s
# [CV 3/5] END ......C=100, degree=4, kernel=poly;, score=0.633 total time=   0.2s
# [CV 4/5] END ......C=100, degree=4, kernel=poly;, score=0.645 total time=   0.2s
# [CV 5/5] END ......C=100, degree=4, kernel=poly;, score=0.650 total time=   0.3s
# [CV 1/5] END .....C=1000, degree=2, kernel=poly;, score=0.572 total time=   1.9s
# [CV 2/5] END .....C=1000, degree=2, kernel=poly;, score=0.633 total time=   2.0s
# [CV 3/5] END .....C=1000, degree=2, kernel=poly;, score=0.610 total time=   2.3s
# [CV 4/5] END .....C=1000, degree=2, kernel=poly;, score=0.591 total time=   1.9s
# [CV 5/5] END .....C=1000, degree=2, kernel=poly;, score=0.609 total time=   2.1s
# [CV 1/5] END .....C=1000, degree=3, kernel=poly;, score=0.636 total time=   4.2s
# [CV 2/5] END .....C=1000, degree=3, kernel=poly;, score=0.662 total time=   4.1s
# [CV 3/5] END .....C=1000, degree=3, kernel=poly;, score=0.649 total time=   4.1s
# [CV 4/5] END .....C=1000, degree=3, kernel=poly;, score=0.612 total time=   2.5s
# [CV 5/5] END .....C=1000, degree=3, kernel=poly;, score=0.622 total time=   3.9s
# [CV 1/5] END .....C=1000, degree=4, kernel=poly;, score=0.626 total time=   1.4s
# [CV 2/5] END .....C=1000, degree=4, kernel=poly;, score=0.651 total time=   2.5s
# [CV 3/5] END .....C=1000, degree=4, kernel=poly;, score=0.649 total time=   1.8s
# [CV 4/5] END .....C=1000, degree=4, kernel=poly;, score=0.638 total time=   1.2s
# [CV 5/5] END .....C=1000, degree=4, kernel=poly;, score=0.650 total time=   2.3s
# SVC(C=10, gamma=1)

# %%
print(svc_mod.best_params_)
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',svc_mod.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',svc_mod.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,svc_mod.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,svc_mod.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.7245508982035929
# Accuracy (memorization) 0.8978439425051334
# F1_score (generalization) 0.7221459855290062
# F1_score (memorization) 0.8975442378019296

# %% [markdown]
# ### Applying Model

# %%
srbf=SVC(C=10.0,kernel='rbf',gamma=1)
srbf.fit(X_train, y_train)
# Out:
# SVC(C=10.0, gamma=1)

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',srbf.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',srbf.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,srbf.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,srbf.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.7245508982035929
# Accuracy (memorization) 0.8978439425051334
# F1_score (generalization) 0.7221459855290062
# F1_score (memorization) 0.8975442378019296
